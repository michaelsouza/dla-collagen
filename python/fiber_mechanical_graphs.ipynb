# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.font_manager as font_manager
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

fontlabel = {'family': 'serif',
        'color':  'black',
        'size': 24,
        }

fontlegend = font_manager.FontProperties(family='serif',
                                   style = 'italic', 
                                   size = 16)

# %%
random.seed(1234)
for i in range(0,10):
    print(random.randint(0,10))
# Out:
# 7
# 1
# 0
# 1
# 9
# 0
# 10
# 1
# 1
# 5

# %%
data1 = pd.read_csv('/home/robert/Dropbox/data/porcet_parts_1_m2.txt', delimiter='\t')
#data2 = pd.read_csv('/home/robert/Dropbox/data/porcet_parts_10_m2.txt', delimiter='\t')
#data3 = pd.read_csv('/home/robert/Dropbox/data/porcet_parts_100_m2.txt', delimiter='\t')
#data4 = pd.read_csv('/home/robert/Dropbox/data/porcet_parts_1000_m2.txt', delimiter='\t')
#data5 = pd.read_csv('/home/robert/Dropbox/data/porcet_parts_10000_m2.txt', delimiter='\t')

x1 = data1['force']
y1 = data1['numParts']
#x2 = data2['force']
#y2 = data2['numParts']
#x3 = data3['force']
#y3 = data3['numParts']
#x4 = data4['force']
#y4 = data4['numParts']
#x5 = data5['force']
#y5 = data5['numParts']

# %%
x1 = [float(i) if(' ' not in i) else float(i[4:]) for i in x1.values]

# %%
plt.figure(figsize=(12,12), dpi = 300)

plt.plot(x1,y1, color = 'black', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 1$')
#plt.plot(x2,y2, color = 'firebrick', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10$')
#plt.plot(x3,y3, color = 'goldenrod', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{2}$')
#plt.plot(x4,y4, color = 'purple', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{3}$')
#plt.plot(x5,y5, color = 'darkgreen', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{4}$')
plt.legend( loc = 'best',prop=fontlegend)
plt.xlim(0,150)
plt.ylim(0,105)
plt.xlabel('Force applied to skeleton, F',fontdict=fontlabel)
plt.ylabel("% particles in skeleton",fontdict=fontlabel)
plt.xticks(size = 20, family = 'serif', weight = 'normal')
plt.yticks(size = 20, family = 'serif', weight = 'normal')
plt.tick_params(direction = 'in',bottom = True, top= True, left= True, right= True )

plt.show()

# %%
density1 = pd.read_csv('/home/robert/Dropbox/data/density_particles_skelento.txt', delimiter='\t')
x = [1, 2, 3, 4, 5]
y1 = density1['density']*100
y2 = density1['particles']*100

# %%
print(y1)
# Out:
# 0     9.406256
# 1    26.047961
# 2    51.422817
# 3    53.015201
# 4    63.383773
# Name: density, dtype: float64

# %%
density1 = pd.read_csv('./density_particles_skeleton_10000.txt', delimiter='\t')
x = [1, 2, 3, 4, 5]
y3 = density1['density']*100
y4 = density1['particles']*100

# %%
print(y3)
# Out:
# 0     8.431889
# 1    25.683004
# 2    50.031848
# 3    48.064177
# 4    46.468350
# Name: density, dtype: float64

# %%
plt.figure(figsize=(12,12), dpi = 300)

plt.plot(x,y1, color = 'black', linewidth = 4,linestyle='-',markersize=12, marker = 's', label = 'Density')
plt.plot(x,y2, color = 'firebrick', linewidth = 4,linestyle='-',markersize=12, marker = 'o', label = 'Percentage of particles in skeleton')
plt.plot(x,y3, color = 'goldenrod', linewidth = 4,linestyle='-',markersize=12, marker = 's', label = 'Density_10000')
plt.plot(x,y4, color = 'purple', linewidth = 4,linestyle='-',markersize=12, marker = 'o', label = 'Percentage of particles in skeleton_10000')
plt.legend( loc = 'best',prop=fontlegend)
plt.xlabel('Surface Diffusion constant,' r'$T_{s}$',fontdict=fontlabel)
plt.ylabel("Density/particles in skeleton(%)",fontdict=fontlabel)
plt.xticks(size = 20, family = 'serif', weight = 'normal')
plt.yticks(size = 20, family = 'serif', weight = 'normal')
plt.xticks(x, [r'$1$', r'$10$', r'$10^{2}$', r'$10^{3}$', r'$10^{4}$'])
plt.tick_params(direction = 'in',bottom = True, top= True, left= True, right= True )

# %%
broken1 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_1_m2.txt',delimiter='\t') 
# broken2 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_10_m2.txt',delimiter='\t') 
# broken3 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_100_m2.txt',delimiter='\t') 
# broken4 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_1000_m2.txt',delimiter='\t') 
# broken5 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_10000_m2.txt',delimiter='\t') 

x1, y1 = broken1['force'], broken1['broken']
# x2, y2 = broken2['force'], broken2['broken']
# x3, y3 = broken3['force'], broken3['broken']
# x4, y4 = broken4['force'], broken4['broken']
# x5, y5 = broken5['force'], broken5['broken']
#print(x1)
#print(y1)

# %%
plt.figure(figsize=(12,12))

plt.plot(x1,y1, color = 'black', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 1$')
# plt.plot(x2,y2, color = 'firebrick', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10$')
# plt.plot(x3,y3, color = 'goldenrod', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{2}$')
# plt.plot(x4,y4, color = 'purple', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{3}$')
# plt.plot(x5,y5, color = 'darkgreen', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{4}$')
plt.legend( loc = 'best',prop=fontlegend)
#plt.xlim(0,400)
plt.xlabel('Force applied to skeleton, F',fontdict=fontlabel)
plt.ylabel("Number of broken bonds",fontdict=fontlabel)
plt.xticks(size = 20, family = 'serif', weight = 'normal')
plt.yticks(size = 20, family = 'serif', weight = 'normal')
plt.tick_params(direction = 'in',bottom = True, top= True, left= True, right= True )

plt.show()

# %%
broken1 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_1_m2.txt',delimiter='\t') 
broken2 = pd.read_csv('/home/robert/Dropbox//data/broken_bonds_10_m2.txt',delimiter='\t') 
broken3 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_100_m2.txt',delimiter='\t') 
broken4 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_1000_m2.txt',delimiter='\t') 
broken5 = pd.read_csv('/home/robert/Dropbox/data/broken_bonds_10000_m2.txt',delimiter='\t') 

x1, y1 = np.log(broken1['force']), np.log(broken1['broken'])
x2, y2 = np.log(broken2['force']), np.log(broken2['broken'])
x3, y3 = np.log(broken3['force']), np.log(broken3['broken'])
x4, y4 = np.log(broken4['force']), np.log(broken4['broken'])
x5, y5 = np.log(broken5['force']), np.log(broken5['broken'])
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure(figsize=(12,12))

plt.plot(x1,y1, color = 'black', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 1$')
plt.plot(x2,y2, color = 'firebrick', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10$')
plt.plot(x3,y3, color = 'goldenrod', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{2}$')
plt.plot(x4,y4, color = 'purple', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{3}$')
plt.plot(x5,y5, color = 'darkgreen', linewidth = 4,linestyle='dashed',markersize=12, label = r'$T_{s} = 10^{4}$')
plt.legend( loc = 'best',prop=fontlegend)
#plt.xlim(0,400)
#plt.xlabel('Force applied to skeleton, F',fontdict=fontlabel)
#plt.ylabel("Number of broken bonds",fontdict=fontlabel)
plt.xticks(size = 20, family = 'serif', weight = 'normal')
plt.yticks(size = 20, family = 'serif', weight = 'normal')
plt.tick_params(direction = 'in',bottom = True, top= True, left= True, right= True )

plt.show()
