# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.font_manager as font_manager
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# %%
x = np.linspace(0,50,25)
x2 = np.linspace(0,50,50)
y1 = x
y2 = x**2/10
y3 = 100+10*np.sin(x)
y4 = 50 - x
y5 = 200 + 5*np.cos(x)

# %%
plt.figure(figsize=(10,7))


fontlabel = {'family': 'serif',
        'color':  'black',
        'weight': 'heavy',
        'style': 'italic',
        'size': 22,
        }

fontlegend = font_manager.FontProperties(family='serif',
                                   weight='heavy',
                                   style = 'italic', 
                                   size = 16)



plt.plot(x,y1, color = 'black', linewidth = 4,linestyle='dashed',markersize=12, marker = 's', label = 'y = x')
plt.plot(x,y2, color = 'firebrick', linewidth = 4,linestyle='dashed',markersize=12, marker = 'o', label = r'y = x^{2}/10')
plt.plot(x,y3, color = 'goldenrod', linewidth = 4,linestyle='dashed',markersize=12, marker = 'v', label = r'y = 100 + 10sin(x)')
plt.plot(x,y4, color = 'purple', linewidth = 4,linestyle='dashed',markersize=12, marker = 'D', label = r'y = 50 - x')
plt.plot(x,y5, color = 'darkgreen', linewidth = 4,linestyle='dashed',markersize=12, marker = '>', label = r'y = 200 + 5cos(x)')
plt.legend( loc = 'best',prop=fontlegend)
plt.xlabel('Tempo(s)',fontdict=fontlabel)
plt.ylabel("Distancia(m)",fontdict=fontlabel)
plt.xticks(size = 20, family = 'serif', weight = 'normal')
plt.yticks(size = 20, family = 'serif', weight = 'normal')
plt.tick_params(direction = 'in',bottom = True, top= True, left= True, right= True )
#plt.yticks(fontdic = fontticks)

# %%
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     232         try:
# --> 233             report = subprocess.check_output(
#     234                 command, cwd=cwd if cwd is not None else self.texcache,
#
# /usr/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#
# /usr/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     515         if check and retcode:
# --> 516             raise CalledProcessError(retcode, process.args,
#     517                                      output=stdout, stderr=stderr)
#
# ...
